# %%
# try from script
# ['rotate', 'shift', 'gaussian_noise', 'shot_noise']
data_config = "/home/bsb2144/daart_utils/configs/data_ibl_t.yaml"
model_config = "/home/bsb2144/daart_utils/configs/model_ibl_t.yaml"
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "all" --fit_tcn --dataset "ibl" --n_samples 5 --fracs ".2" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t2.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "rotate" --fit_tcn --dataset "ibl" --n_samples 5 --fracs ".2" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t3.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "shift" --fit_tcn --dataset "ibl" --n_samples 5 --fracs ".2" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t4.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "gauss" --fit_tcn --dataset "ibl" --n_samples 5 --fracs ".2" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t5.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "shot" --fit_tcn --dataset "ibl" --n_samples 5 --fracs ".2" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t6.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "nope" --fit_tcn --dataset "ibl" --n_samples 5 --fracs ".2" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
# ...

# %%
import logging
import sys

logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s',
                     level=logging.INFO, stream=sys.stdout)

# %%
# try from script
data_config = "/home/bsb2144/daart_utils/configs/data_ibl_t.yaml"
model_config = "/home/bsb2144/daart_utils/configs/model_ibl_t.yaml"
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t.yaml"

# %%
#gmdgm - nt
# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "rwyawry" --fit_tcn --dataset "ibl" --n_samples 1 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_ibl_t.yaml" --model "/home/bsb2144/daart_utils/configs/model_ibl_t.yaml" --train "/home/bsb2144/daart_utils/configs/train_ibl_t.yaml"
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: churchlandlab_CSHL045_2020-02-27-001;cortexlab_KS020_2020-02-06-001;hoferlab_SWC_043_2020-09-15-001;mrsicflogellab_SWC_052_2020-10-22-001;wittenlab_ibl_witten_27_2021-01-21-001
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
# ...

# %%
# !python /home/bsb2144/daart/examples/fit_models.py --data_config "/home/bsb2144/daart_utils/configs/data_ibl_t.yaml" --model_config "/home/bsb2144/daart_utils/configs/model_ibl_t.yaml" --train_config "/home/bsb2144/daart_utils/configs/train_ibl_t.yaml"
# Out:
# DATA CONFIG:
#     input_type: markers
#     output_size: 5
#     n_observed_classes: 5
#     n_aug_classes: 0
#     ignore_class: 0
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     expt_ids_test: churchlandlab_CSHL045_2020-02-27-001;cortexlab_KS020_2020-02-06-001;hoferlab_SWC_043_2020-09-15-001;mrsicflogellab_SWC_052_2020-10-22-001;wittenlab_ibl_witten_27_2021-01-21-001
#     data_dir: /home/bsb2144/daart_utils/data/ibl/
#     results_dir: /home/bsb2144/daart/results_data/ibl/
#
# MODEL CONFIG:
#     tt_experiment_name: test_all
#     model_class: segmenter
# ...

# %%
tjrsyr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_33082/3825914213.py in <module>
# ----> 1 tjrsyr
#
# NameError: name 'tjrsyr' is not defined
