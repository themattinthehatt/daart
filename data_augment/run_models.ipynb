# %%
# try from script
# ['rotate', 'shift', 'gaussian_noise', 'shot_noise']
data_config = "/home/bsb2144/daart_utils/configs/data_ibl_t.yaml"
model_config = "/home/bsb2144/daart_utils/configs/model_ibl_t.yaml"
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "t28" --fit_tcn --dataset "ibl" --n_samples 5 --fracs "1" --data $data_config --model $model_config --train $train_config
# Out:
# here
# mod types ['dtcn']
# call grind
# main
# gpu_ids ['0']
# run_main
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002', '3bcb81b4-d9ca-4fc9-a1cd-353a966239ca', '3f859b5c-e73a-4044-b49e-34bb81e96715', '5ae68c54-2897-4d3a-8120-426150704385', '6f09ba7e-e3ce-44b0-932b-c003fb44fb89', '3638d102-e8b6-4230-8742-e548cd87a949', '8928f98a-b411-497e-aa4b-aa752434686d', '73918ae1-e4fd-4c18-b132-00cb555b1ad2', 'b03fbc44-3d8e-4a6c-8a50-5ea3498568e0', 'b22f694e-4a34-4142-ab9d-2556c3487086', 'b196a2ad-511b-4e90-ac99-b5a29ad25c22', 'c7bf2d49-4937-4597-b307-9f39cb1c7b16', 'c7248e09-8c0d-40f2-9eb4-700a8973d8c8', 'ca4ecb4c-4b60-4723-9b9e-2c54a6290a53', 'd0ea3148-948d-4817-94f8-dcaf2342bbbe', 'd23a44ef-1402-4ed7-97f5-47e9a7a504d9', 'dc962048-89bb-4e6a-96a9-b062a2be1426', 'e535fb62-e245-4a48-b119-88ce62a6fe67', 'f140a2ec-fd49-4814-994a-fe3476f14e66', 'f115196e-8dfe-4d2a-8af3-8206d93c1729', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002;3bcb81b4-d9ca-4fc9-a1cd-353a966239ca;3f859b5c-e73a-4044-b49e-34bb81e96715;5ae68c54-2897-4d3a-8120-426150704385;6f09ba7e-e3ce-44b0-932b-c003fb44fb89;3638d102-e8b6-4230-8742-e548cd87a949;8928f98a-b411-497e-aa4b-aa752434686d;73918ae1-e4fd-4c18-b132-00cb555b1ad2;b03fbc44-3d8e-4a6c-8a50-5ea3498568e0;b22f694e-4a34-4142-ab9d-2556c3487086;b196a2ad-511b-4e90-ac99-b5a29ad25c22;c7bf2d49-4937-4597-b307-9f39cb1c7b16;c7248e09-8c0d-40f2-9eb4-700a8973d8c8;ca4ecb4c-4b60-4723-9b9e-2c54a6290a53;d0ea3148-948d-4817-94f8-dcaf2342bbbe;d23a44ef-1402-4ed7-97f5-47e9a7a504d9;dc962048-89bb-4e6a-96a9-b062a2be1426;e535fb62-e245-4a48-b119-88ce62a6fe67;f140a2ec-fd49-4814-994a-fe3476f14e66;f115196e-8dfe-4d2a-8af3-8206d93c1729;cortexlab_KS020_2020-02-06-001;hoferlab_SWC_043_2020-09-15-001;mrsicflogellab_SWC_052_2020-10-22-001;wittenlab_ibl_witten_27_2021-01-21-001
#     ignore_class: 0
#     input_type: features-posvel2
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 0
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: t28-28-good_sample-0_features-posvel2
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: None
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
# Generator contains 28 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
# 3bcb81b4-d9ca-4fc9-a1cd-353a966239ca
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/3bcb81b4-d9ca-4fc9-a1cd-353a966239ca_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/e535fb62-e245-4a48-b119-88ce62a6fe67_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/e535fb62-e245-4a48-b119-88ce62a6fe67_labels.csv')])
# f140a2ec-fd49-4814-994a-fe3476f14e66
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/f140a2ec-fd49-4814-994a-fe3476f14e66_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/f140a2ec-fd49-4814-994a-fe3476f14e66_labels.csv')])
# f115196e-8dfe-4d2a-8af3-8206d93c1729
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/f115196e-8dfe-4d2a-8af3-8206d93c1729_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/f115196e-8dfe-4d2a-8af3-8206d93c1729_labels.csv')])
# cortexlab_KS020_2020-02-06-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/cortexlab_KS020_2020-02-06-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/cortexlab_KS020_2020-02-06-001_labels.csv')])
# hoferlab_SWC_043_2020-09-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/hoferlab_SWC_043_2020-09-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_043_2020-09-15-001_labels.csv')])
# mrsicflogellab_SWC_052_2020-10-22-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/mrsicflogellab_SWC_052_2020-10-22-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_052_2020-10-22-001_labels.csv')])
# wittenlab_ibl_witten_27_2021-01-21-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel2/wittenlab_ibl_witten_27_2021-01-21-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_27_2021-01-21-001_labels.csv')])
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#   2%|▊                                         | 10/502 [00:43<36:04,  4.40s/it]

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t2.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "rotate" --fit_tcn --dataset "ibl" --n_samples 5 --fracs "1" --data $data_config --model $model_config --train $train_config
# Out:
# here
# mod types ['dtcn']
# call grind
# main
# gpu_ids ['0']
# run_main
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel2
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 0
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: rotate-5-good_sample-0_features-posvel2
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['rotate']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
# ^C
# Traceback (most recent call last):
#   File "/home/bsb2144/daart/examples/fit_models.py", line 206, in <module>
#     gpu_ids=gpu_ids)
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/test_tube/argparse_hopt.py", line 325, in optimize_parallel_gpu
#     results = self.pool.map(optimize_parallel_gpu_private, self.trials)
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/multiprocessing/pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/multiprocessing/pool.py", line 651, in get
#     self.wait(timeout)
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/multiprocessing/pool.py", line 648, in wait
#     self._event.wait(timeout)
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/threading.py", line 552, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/threading.py", line 296, in wait
#     waiter.acquire()
# KeyboardInterrupt
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/test_tube/argparse_hopt.py", line 39, in optimize_parallel_gpu_private
#     results = train_function(trial_params, gpu_id_set)
#   File "/home/bsb2144/daart/examples/fit_models.py", line 82, in run_main
#     train_model(hparams)
#   File "/home/bsb2144/daart/examples/fit_models.py", line 98, in train_model
#     data_gen = build_data_generator(hparams)
#   File "/share/ctn/users/bsb2144/daart/daart/utils.py", line 169, in build_data_generator
#     batch_transform_params=hparams.get('batch_transform_params', {})
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/share/ctn/users/bsb2144/daart/daart/data.py", line 547, in __init__
#     sequence_pad=sequence_pad, input_type=input_type))
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/share/ctn/users/bsb2144/daart/daart/data.py", line 273, in __init__
#     self.load_data(sequence_length, input_type)
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/share/ctn/users/bsb2144/daart/daart/data.py", line 411, in load_data
#     labels, label_names = load_label_csv(self.paths[signal])
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/share/ctn/users/bsb2144/daart/daart/data.py", line 964, in load_label_csv
#     filepath, delimiter=',', dtype=int, encoding=None, skip_header=1)[:, 1:]
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/numpy/lib/npyio.py", line 2254, in genfromtxt
#     output = np.array(data, dtype)
# KeyboardInterrupt

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t3.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "shift" --fit_tcn --dataset "ibl" --n_samples 5 --fracs "1" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 0
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#   0%|                                                   | 0/502 [00:00<?, ?it/s]/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
# 100%|█████████████████████████████████████████| 502/502 [06:17<00:00,  1.33it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 1
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 1
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
# 100%|█████████████████████████████████████████| 502/502 [06:15<00:00,  1.34it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
# 100%|█████████████████████████████████████████| 502/502 [06:12<00:00,  1.35it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shift-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shift']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
# ...
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
# 100%|█████████████████████████████████████████| 502/502 [06:12<00:00,  1.35it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t4.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "gauss" --fit_tcn --dataset "ibl" --n_samples 5 --fracs "1" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 0
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#   0%|                                                   | 0/502 [00:00<?, ?it/s]/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
# 100%|█████████████████████████████████████████| 502/502 [07:34<00:00,  1.10it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 1
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 1
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
# 100%|█████████████████████████████████████████| 502/502 [07:35<00:00,  1.10it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
# 100%|█████████████████████████████████████████| 502/502 [07:33<00:00,  1.11it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: gauss-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['gaussian_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
# ...
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
# 100%|█████████████████████████████████████████| 502/502 [07:39<00:00,  1.09it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t5.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "shot" --fit_tcn --dataset "ibl" --n_samples 5 --fracs "1" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 0
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#   0%|                                                   | 0/502 [00:00<?, ?it/s]/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
# 100%|█████████████████████████████████████████| 502/502 [07:11<00:00,  1.16it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 1
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 1
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
# 100%|█████████████████████████████████████████| 502/502 [07:11<00:00,  1.16it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
# 100%|█████████████████████████████████████████| 502/502 [07:11<00:00,  1.16it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: shot-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
# ...
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
# 100%|█████████████████████████████████████████| 502/502 [07:10<00:00,  1.17it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "

# %%
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t6.yaml"

# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "nope" --fit_tcn --dataset "ibl" --n_samples 5 --fracs "1" --data $data_config --model $model_config --train $train_config
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 0
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#   0%|                                                   | 0/502 [00:00<?, ?it/s]/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
# 100%|█████████████████████████████████████████| 502/502 [05:46<00:00,  1.45it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 1
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 1
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
# 100%|█████████████████████████████████████████| 502/502 [05:47<00:00,  1.45it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 2
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
# 100%|█████████████████████████████████████████| 502/502 [05:44<00:00,  1.46it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: ['churchlandlab_CSHL045_2020-02-27-001', 'cortexlab_KS020_2020-02-06-001', 'hoferlab_SWC_043_2020-09-15-001', 'mrsicflogellab_SWC_052_2020-10-22-001', 'wittenlab_ibl_witten_27_2021-01-21-001']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 3
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: nope-5-good_sample-0_features-posvel
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: []
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 500
#     max_epochs: 501
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# ...
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_009_2020-02-27-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/danlab_DY_018_2020-10-15-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/hoferlab_SWC_061_2020-11-23-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/mrsicflogellab_SWC_058_2020-12-11-001_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/features-posvel/wittenlab_ibl_witten_26_2021-01-27-002_labeled.csv'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(6, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
# 100%|█████████████████████████████████████████| 502/502 [05:42<00:00,  1.47it/s]
# /home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/torch/nn/functional.py:1338: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "

# %%
import logging
import sys

logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s',
                     level=logging.INFO, stream=sys.stdout)

# %%
# try from script
data_config = "/home/bsb2144/daart_utils/configs/data_ibl_t.yaml"
model_config = "/home/bsb2144/daart_utils/configs/model_ibl_t.yaml"
train_config = "/home/bsb2144/daart_utils/configs/train_ibl_t.yaml"

# %%
#gmdgm - nt
# !python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre "rwyawry" --fit_tcn --dataset "ibl" --n_samples 1 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_ibl_t.yaml" --model "/home/bsb2144/daart_utils/configs/model_ibl_t.yaml" --train "/home/bsb2144/daart_utils/configs/train_ibl_t.yaml"
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/ibl
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_test: churchlandlab_CSHL045_2020-02-27-001;cortexlab_KS020_2020-02-06-001;hoferlab_SWC_043_2020-09-15-001;mrsicflogellab_SWC_052_2020-10-22-001;wittenlab_ibl_witten_27_2021-01-21-001
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     n_aug_classes: 0
#     n_observed_classes: 5
#     output_size: 5
#     results_dir: /home/bsb2144/daart/results_daart/ibl
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     backbone_transition: linear
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     focal_loss: False
#     gamma: 4
#     kl_y_weight: 1
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end: 900
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_z_weight: 1
#     lambda_pred: 0
#     lambda_recon: 0
#     lambda_strong: 100
#     lambda_task: 0
#     lambda_weak: 0
#     model_class: segmenter
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     rng_seed_model: 0
#     semi_supervised_algo: None
#     temporal_inference: False
#     tt_experiment_name: rwyawry-5-good_sample-0_markers
#     variational: False
#
# TRAIN CONFIG:
#     batch_transforms: ['rotate', 'shift', 'gaussian_noise', 'shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 50
#     max_epochs: 51
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
# pre gen
# pre DG
# h dict_keys(['label_names', 'batch_transforms', 'batch_transform_params', 'data_config', 'model_config', 'train_config', 'data_dir', 'expt_ids', 'expt_ids_test', 'expt_ids_to_keep', 'ignore_class', 'input_type', 'n_aug_classes', 'n_observed_classes', 'output_size', 'results_dir', 'activation', 'ann_end', 'ann_start', 'ann_weight', 'anneal_end_y', 'anneal_start_y', 'backbone', 'backbone_decoder', 'backbone_dynamic', 'backbone_generative', 'backbone_inference', 'backbone_transition', 'bidirectional', 'classifier_type', 'dropout', 'entropy_start_anneal', 'entropy_weight', 'focal_loss', 'gamma', 'kl_y_weight', 'kl_y_weight_uniform', 'kl_y_weight_uniform_end', 'kl_y_weight_uniform_end_val', 'kl_y_weight_uniform_start_anneal', 'kl_z_weight', 'lambda_pred', 'lambda_recon', 'lambda_strong', 'lambda_task', 'lambda_weak', 'model_class', 'n_hid_layers', 'n_hid_units', 'n_lags', 'n_latents', 'prob_threshold', 'qy_x_temperature', 'rng_seed_model', 'semi_supervised_algo', 'temporal_inference', 'tt_experiment_name', 'variational', 'min_epochs', 'max_epochs', 'learning_rate', 'sequence_length', 'batch_size', 'l2_reg', 'val_check_interval', 'enable_early_stop', 'early_stop_history', 'save_last_model', 'train_frac', 'trial_splits', 'rng_seed_train', 'plot_train_curves', 'num_labels_remove', 'num_labels_keep_per_class', 'remove_labels', 'device', 'gpus_vis', 'tt_n_cpu_trials', 'tt_n_cpu_workers', 'hpc_exp_number', 'expt_dir', 'model_dir', 'version', 'tt_version_dir', 'sequence_pad'])
# parasm {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
# innit
# bacthes p
# bacthes
# post
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/danlab_DY_009_2020-02-27-001_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/danlab_DY_018_2020-10-15-001_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/hoferlab_SWC_061_2020-11-23-001_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/mrsicflogellab_SWC_058_2020-12-11-001_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/wittenlab_ibl_witten_26_2021-01-27-002_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(3, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)
#
#
# Caught exception in worker thread name 'batch_transforms' is not defined
# Traceback (most recent call last):
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/test_tube/argparse_hopt.py", line 39, in optimize_parallel_gpu_private
#     results = train_function(trial_params, gpu_id_set)
#   File "/home/bsb2144/daart/examples/fit_models.py", line 79, in run_main
#     train_model(hparams)
#   File "/home/bsb2144/daart/examples/fit_models.py", line 132, in train_model
#     trainer = Trainer(**hparams, callbacks=callbacks)
#   File "/home/bsb2144/miniconda3/envs/daart2/lib/python3.7/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/share/ctn/users/bsb2144/daart/daart/train.py", line 277, in __init__
#     self.batch_transforms = batch_transforms
# NameError: name 'batch_transforms' is not defined

# %%
# !python /home/bsb2144/daart/examples/fit_models.py --data_config "/home/bsb2144/daart_utils/configs/data_ibl_t.yaml" --model_config "/home/bsb2144/daart_utils/configs/model_ibl_t.yaml" --train_config "/home/bsb2144/daart_utils/configs/train_ibl_t.yaml"
# Out:
# DATA CONFIG:
#     input_type: markers
#     output_size: 5
#     n_observed_classes: 5
#     n_aug_classes: 0
#     ignore_class: 0
#     label_names: ['background', 'still', 'move', 'wheel_turn', 'groom']
#     expt_ids: ['danlab_DY_009_2020-02-27-001', 'danlab_DY_018_2020-10-15-001', 'hoferlab_SWC_061_2020-11-23-001', 'mrsicflogellab_SWC_058_2020-12-11-001', 'wittenlab_ibl_witten_26_2021-01-27-002']
#     expt_ids_to_keep: danlab_DY_009_2020-02-27-001;danlab_DY_018_2020-10-15-001;hoferlab_SWC_061_2020-11-23-001;mrsicflogellab_SWC_058_2020-12-11-001;wittenlab_ibl_witten_26_2021-01-27-002
#     expt_ids_test: churchlandlab_CSHL045_2020-02-27-001;cortexlab_KS020_2020-02-06-001;hoferlab_SWC_043_2020-09-15-001;mrsicflogellab_SWC_052_2020-10-22-001;wittenlab_ibl_witten_27_2021-01-21-001
#     data_dir: /home/bsb2144/daart_utils/data/ibl/
#     results_dir: /home/bsb2144/daart/results_data/ibl/
#
# MODEL CONFIG:
#     tt_experiment_name: test_all
#     model_class: segmenter
#     activation: lrelu
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
#     bidirectional: True
#     classifier_type: multiclass
#     dropout: 0.1
#     entropy_start_anneal: 500
#     entropy_weight: 0
#     backbone_dynamic: linear
#     backbone_transition: linear
#     lambda_strong: 100
#     ann_weight: 1
#     ann_start: 0
#     ann_end: 100
#     kl_z_weight: 1
#     kl_y_weight: 1
#     rng_seed_model: 0
#     temporal_inference: False
#     kl_y_weight_uniform: 0
#     kl_y_weight_uniform_end_val: 0
#     kl_y_weight_uniform_start_anneal: 800
#     kl_y_weight_uniform_end: 900
#     focal_loss: False
#     gamma: 4
#     lambda_task: 0
#     lambda_weak: 0
#     n_hid_layers: 2
#     n_hid_units: 32
#     n_lags: 4
#     n_latents: 9
#     prob_threshold: 0.9
#     qy_x_temperature: 1
#     semi_supervised_algo: None
#     variational: False
#     lambda_pred: 0
#     lambda_recon: 0
#
# TRAIN CONFIG:
#     batch_transforms: ['rotate', 'shift', 'gaussian_noise', 'shot_noise']
#     batch_transform_params: {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
#     min_epochs: 50
#     max_epochs: 51
#     learning_rate: 0.0001
#     sequence_length: 1000
#     batch_size: 8
#     l2_reg: 0
#     val_check_interval: 100000
#     enable_early_stop: False
#     early_stop_history: 5
#     save_last_model: True
#     train_frac: 1
#     trial_splits: 10;0;0;0
#     rng_seed_train: 0
#     plot_train_curves: True
#     num_labels_remove: 4990
#     num_labels_keep_per_class: 5
#     remove_labels: False
#     device: cuda
#     gpus_vis: 0
#     tt_n_cpu_trials: 100
#     tt_n_cpu_workers: 5
#
#
# pre gen
# pre DG
# h dict_keys(['label_names', 'batch_transforms', 'batch_transform_params', 'data_config', 'model_config', 'train_config', 'input_type', 'output_size', 'n_observed_classes', 'n_aug_classes', 'ignore_class', 'expt_ids', 'expt_ids_to_keep', 'expt_ids_test', 'data_dir', 'results_dir', 'tt_experiment_name', 'model_class', 'activation', 'anneal_end_y', 'anneal_start_y', 'backbone', 'backbone_decoder', 'backbone_generative', 'backbone_inference', 'bidirectional', 'classifier_type', 'dropout', 'entropy_start_anneal', 'entropy_weight', 'backbone_dynamic', 'backbone_transition', 'lambda_strong', 'ann_weight', 'ann_start', 'ann_end', 'kl_z_weight', 'kl_y_weight', 'rng_seed_model', 'temporal_inference', 'kl_y_weight_uniform', 'kl_y_weight_uniform_end_val', 'kl_y_weight_uniform_start_anneal', 'kl_y_weight_uniform_end', 'focal_loss', 'gamma', 'lambda_task', 'lambda_weak', 'n_hid_layers', 'n_hid_units', 'n_lags', 'n_latents', 'prob_threshold', 'qy_x_temperature', 'semi_supervised_algo', 'variational', 'lambda_pred', 'lambda_recon', 'min_epochs', 'max_epochs', 'learning_rate', 'sequence_length', 'batch_size', 'l2_reg', 'val_check_interval', 'enable_early_stop', 'early_stop_history', 'save_last_model', 'train_frac', 'trial_splits', 'rng_seed_train', 'plot_train_curves', 'num_labels_remove', 'num_labels_keep_per_class', 'remove_labels', 'device', 'gpus_vis', 'tt_n_cpu_trials', 'tt_n_cpu_workers', 'hpc_exp_number', 'expt_dir', 'model_dir', 'version', 'tt_version_dir', 'sequence_pad'])
# parasm {'angle': 10, 'shift_max': 0.1, 'sigma': 0.01, 'shot_max': 1}
# innit
# bacthes p
# bacthes
# post
# Generator contains 5 SingleDataset objects:
# danlab_DY_009_2020-02-27-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/danlab_DY_009_2020-02-27-001_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_009_2020-02-27-001_labels.csv')])
# danlab_DY_018_2020-10-15-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/danlab_DY_018_2020-10-15-001_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/danlab_DY_018_2020-10-15-001_labels.csv')])
# hoferlab_SWC_061_2020-11-23-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/hoferlab_SWC_061_2020-11-23-001_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/hoferlab_SWC_061_2020-11-23-001_labels.csv')])
# mrsicflogellab_SWC_058_2020-12-11-001
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/mrsicflogellab_SWC_058_2020-12-11-001_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/mrsicflogellab_SWC_058_2020-12-11-001_labels.csv')])
# wittenlab_ibl_witten_26_2021-01-27-002
#     signals: ['markers', 'labels_strong']
#     transforms: OrderedDict([('markers', ZScore()), ('labels_strong', None)])
#     paths: OrderedDict([('markers', '/home/bsb2144/daart_utils/data/ibl/markers/wittenlab_ibl_witten_26_2021-01-27-002_labeled.npy'), ('labels_strong', '/home/bsb2144/daart_utils/data/ibl/labels-hand/wittenlab_ibl_witten_26_2021-01-27-002_labels.csv')])
#
#
# DTCN architecture
# ------------------------
# Encoder:
#     0: DilationBlock
#         0: Conv1d(3, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(4,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#     1: DilationBlock
#         0: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         1: LeakyReLU(negative_slope=0.05)
#         2: Dropout2d(p=0.1, inplace=False)
#         3: Conv1d(32, 32, kernel_size=(9,), stride=(1,), padding=(8,), dilation=(2,))
#         4: LeakyReLU(negative_slope=0.05)
#         5: Dropout2d(p=0.1, inplace=False)
#         6: residual connection
#         7: LeakyReLU(negative_slope=0.05)
#
#
# Classifier:
#     0: Linear(in_features=32, out_features=5, bias=True)

# %%
tjrsyr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_33082/3825914213.py in <module>
# ----> 1 tjrsyr
#
# NameError: name 'tjrsyr' is not defined
