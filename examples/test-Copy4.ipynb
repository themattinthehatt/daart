# %%
# Timing tests (train)

# %%
# fly

data_config = "/home/bsb2144/daart_utils/configs/data_fly-5b.yaml"
model_config = "/home/bsb2144/daart_utils/configs/model_flyb.yaml"
train_config = "/home/bsb2144/daart_utils/configs/train_flyb.yaml"
ds = "fly-5"

# !python fit_models_subsample_loop.py --pre "s" --fit_rsldsm  --dataset $ds --n_samples 5 --fracs "1" --data $data_config --model $model_config --train $train_config
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/fly-5
#     expt_ids: ['2019_08_07_fly2', '2019_08_08_fly1', '2019_08_20_fly2', '2019_10_10_fly3', '2019_10_14_fly3']
#     expt_ids_test: ['2019_06_26_fly2', '2019_08_14_fly1', '2019_08_20_fly3', '2019_10_14_fly2', '2019_10_21_fly1']
#     expt_ids_to_keep: 2019_08_07_fly2;2019_08_08_fly1;2019_08_20_fly2;2019_10_10_fly3;2019_10_14_fly3
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'walk', 'front_groom', 'back_groom', 'abdomen-move']
#     n_aug_classes: 0
#     n_observed_classes: 6
#     output_size: 6
#     results_dir: /home/bsb2144/daart/results_daart/fly-5
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# !python fit_models_subsample_loop.py --pre "time_tcn" --fit_tcn  --dataset $ds --n_samples 5 --fracs "1" --data $data_config --model $model_config --train $train_config
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/fly-5
#     expt_ids: ['2019_08_07_fly2', '2019_08_08_fly1', '2019_08_20_fly2', '2019_10_10_fly3', '2019_10_14_fly3']
#     expt_ids_test: ['2019_06_26_fly2', '2019_08_14_fly1', '2019_08_20_fly3', '2019_10_14_fly2', '2019_10_21_fly1']
#     expt_ids_to_keep: 2019_08_07_fly2;2019_08_08_fly1;2019_08_20_fly2;2019_10_10_fly3;2019_10_14_fly3
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'walk', 'front_groom', 'back_groom', 'abdomen-move']
#     n_aug_classes: 0
#     n_observed_classes: 6
#     output_size: 6
#     results_dir: /home/bsb2144/daart/results_daart/fly-5
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# try from script
data_config = "/home/bsb2144/daart_utils/configs/data_fly-5c.yaml"
model_config = "/home/bsb2144/daart_utils/configs/model_flyc.yaml"
train_config = "/home/bsb2144/daart_utils/configs/train_flyc.yaml"
ds = "fly-5"

# !python loop_unlabeled.py --pre "s3_5vids" --fit_rsldsm --nv 5 --dataset $ds --n_samples 5 --fracs ".4" --data $data_config --model $model_config --train $train_config
# Out:
# here
# expt ids ['2019_08_07_fly2', '2019_08_08_fly1', '2019_08_20_fly2', '2019_10_10_fly3', '2019_10_14_fly3']
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/fly-5
#     expt_ids: ['2019_08_07_fly2', '2019_08_08_fly1', '2019_08_20_fly2', '2019_10_10_fly3', '2019_10_14_fly3']
#     expt_ids_test: ['2019_06_26_fly2', '2019_08_14_fly1', '2019_08_20_fly3', '2019_10_14_fly2', '2019_10_21_fly1']
#     expt_ids_to_keep: 2019_08_07_fly2;2019_08_08_fly1
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'still', 'walk', 'front_groom', 'back_groom', 'abdomen-move']
#     n_aug_classes: 0
#     n_observed_classes: 6
#     output_size: 6
#     results_dir: /home/bsb2144/daart/results_daart/fly-5
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
# ...

# %%
# try from script
data_config = "/home/bsb2144/daart_utils/configs/data_fly-5c.yaml"
model_config = "/home/bsb2144/daart_utils/configs/model_flyc.yaml"
train_config = "/home/bsb2144/daart_utils/configs/train_flyc.yaml"
ds = "fly-5"

# !python loop_unlabeled.py --pre "s3_5vids" --fit_rsldsm --nv 5 --dataset $ds --n_samples 5 --fracs ".4" --data $data_config --model $model_config --train $train_config
# Out:
# here
# expt ids ['2019_08_07_fly2', '2019_08_08_fly1', '2019_08_20_fly2', '2019_10_10_fly3', '2019_10_14_fly3']
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/fly-5
#     expt_ids: ['2019_08_07_fly2', '2019_08_08_fly1', '2019_08_20_fly2', '2019_10_10_fly3', '2019_10_14_fly3']
#     expt_ids_test: ['2019_06_26_fly2', '2019_08_14_fly1', '2019_08_20_fly3', '2019_10_14_fly2', '2019_10_21_fly1']
#     expt_ids_to_keep: 2019_08_07_fly2;2019_08_08_fly1
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'still', 'walk', 'front_groom', 'back_groom', 'abdomen-move']
#     n_aug_classes: 0
#     n_observed_classes: 6
#     output_size: 6
#     results_dir: /home/bsb2144/daart/results_daart/fly-5
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
# ...

# %%
# tree results

# xgb
# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "xgb" --fit_xgb --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# rf
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"

# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# !python fit_models_subsample_loop.py --pre "rf" --fit_rf --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft2.yaml"
# Out:
# here
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# oft - m/pv
# tcn
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# ...

# %%
#rsl
# !python fit_models_subsample_loop.py --pre "rsl" --linear --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_15
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
# ...

# %%
# !python fit_models_subsample_loop.py --pre "rsl" --linear --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23
#     ignore_class: 0
#     input_type: markers
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
# ...

# %%
# rsln
# !python fit_models_subsample_loop.py --pre "rsln" --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: mlp
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# !python fit_models_subsample_loop.py --pre "rsln" --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"

# %%
# gmdgm - tcn
# !python fit_models_subsample_loop.py --pre "gm" --temporal --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"

# %%
# !python fit_models_subsample_loop.py --pre "gm" --temporal --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"

# %%
#gmdgm - nt
# !python fit_models_subsample_loop.py --pre "gmnt" --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"

# %%
# !python fit_models_subsample_loop.py --pre "gmnt" --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1;.8;.6;.4" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"

# %%
# sets of 5s
# rsl
# !python fit_models_subsample_loop.py --pre "rsl" --linear --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# !python fit_models_subsample_loop.py --pre "rsl" --linear --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit

# %%
# rsln
# !python fit_models_subsample_loop.py --pre "rsln" --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# !python fit_models_subsample_loop.py --pre "rsln" --fit_rsldsm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# here
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit
# Experiment exists! Aborting fit

# %%
# gmdgm-tcn
# !python fit_models_subsample_loop.py --pre "gm" --temporal --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# !python fit_models_subsample_loop.py --pre "gm" --temporal --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# gmdgm-nt
# !python fit_models_subsample_loop.py --pre "gmnt"  --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# !python fit_models_subsample_loop.py --pre "gmnt"  --fit_gmdgm --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...

# %%
# tcn
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# !python fit_models_subsample_loop.py --pre "tcn" --fit_tcn --dataset "mouse-oft-aligned" --n_samples 5 --fracs "1" --data "/home/bsb2144/daart_utils/configs/data_oft2.yaml" --model "/home/bsb2144/daart_utils/configs/model_oft2.yaml" --train "/home/bsb2144/daart_utils/configs/train_oft.yaml"
# Out:
# here
# NZ:  0
#
# DATA CONFIG:
#     data_dir: /home/bsb2144/daart_utils/data/mouse-oft-aligned
#     expt_ids: ['OFT_5', 'OFT_6', 'OFT_11', 'OFT_12', 'OFT_14', 'OFT_15', 'OFT_16', 'OFT_23', 'OFT_24', 'OFT_38']
#     expt_ids_test: ['OFT_39', 'OFT_41', 'OFT_43', 'OFT_44', 'OFT_49', 'OFT_50', 'OFT_51', 'OFT_52', 'OFT_54', 'OFT_58']
#     expt_ids_to_keep: OFT_5;OFT_6;OFT_11;OFT_12;OFT_14;OFT_15;OFT_16;OFT_23;OFT_24;OFT_38
#     ignore_class: 0
#     input_type: features-posvel
#     label_names: ['background', 'supported', 'unsupported', 'grooming']
#     n_aug_classes: 0
#     n_observed_classes: 4
#     output_size: 4
#     results_dir: /home/bsb2144/daart/results_daart/mouse-oft-aligned
#
# MODEL CONFIG:
#     activation: lrelu
#     ann_end: 100
#     ann_start: 0
#     ann_weight: 1
#     anneal_end_y: 125
#     anneal_start_y: 25
#     backbone: dtcn
#     backbone_decoder: mlp
#     backbone_dynamic: linear
#     backbone_generative: dtcn
#     backbone_inference: dtcn
# ...
