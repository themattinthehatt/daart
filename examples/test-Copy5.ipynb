# %%
# tcn vel
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv3 --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c1.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml
# Out:
# here
# mod types ['dtcn']
# frac 1
# n_sessions 68
# ['mouse001', 'mouse002', 'mouse003', 'mouse004', 'mouse005', 'mouse006', 'mouse007', 'mouse008', 'mouse009', 'mouse010', 'mouse011', 'mouse012', 'mouse013', 'mouse014', 'mouse015', 'mouse016', 'mouse017', 'mouse018', 'mouse019', 'mouse020', 'mouse021', 'mouse022', 'mouse023', 'mouse024', 'mouse025', 'mouse026', 'mouse027', 'mouse028', 'mouse029', 'mouse030', 'mouse031', 'mouse032', 'mouse033', 'mouse034', 'mouse035', 'mouse037', 'mouse038', 'mouse039', 'mouse040', 'mouse041', 'mouse042', 'mouse044', 'mouse045', 'mouse046', 'mouse047', 'mouse048', 'mouse049', 'mouse050', 'mouse051', 'mouse052', 'mouse053', 'mouse054', 'mouse055', 'mouse056', 'mouse057', 'mouse058', 'mouse059', 'mouse060', 'mouse061', 'mouse062', 'mouse063', 'mouse064', 'mouse065', 'mouse066', 'mouse067', 'mouse068', 'mouse069', 'mouse070']
# ...

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c1.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c1.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml
# Out:
# here
# mod types ['dtcn']
# frac 1
# n_sessions 68
# ['mouse001', 'mouse002', 'mouse003', 'mouse004', 'mouse005', 'mouse006', 'mouse007', 'mouse008', 'mouse009', 'mouse010', 'mouse011', 'mouse012', 'mouse013', 'mouse014', 'mouse015', 'mouse016', 'mouse017', 'mouse018', 'mouse019', 'mouse020', 'mouse021', 'mouse022', 'mouse023', 'mouse024', 'mouse025', 'mouse026', 'mouse027', 'mouse028', 'mouse029', 'mouse030', 'mouse031', 'mouse032', 'mouse033', 'mouse034', 'mouse035', 'mouse037', 'mouse038', 'mouse039', 'mouse040', 'mouse041', 'mouse042', 'mouse044', 'mouse045', 'mouse046', 'mouse047', 'mouse048', 'mouse049', 'mouse050', 'mouse051', 'mouse052', 'mouse053', 'mouse054', 'mouse055', 'mouse056', 'mouse057', 'mouse058', 'mouse059', 'mouse060', 'mouse061', 'mouse062', 'mouse063', 'mouse064', 'mouse065', 'mouse066', 'mouse067', 'mouse068', 'mouse069', 'mouse070']
# ...

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c2.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c2.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml
# Out:
# here
# mod types ['dtcn']
# frac 1
# n_sessions 68
# ['mouse001', 'mouse002', 'mouse003', 'mouse004', 'mouse005', 'mouse006', 'mouse007', 'mouse008', 'mouse009', 'mouse010', 'mouse011', 'mouse012', 'mouse013', 'mouse014', 'mouse015', 'mouse016', 'mouse017', 'mouse018', 'mouse019', 'mouse020', 'mouse021', 'mouse022', 'mouse023', 'mouse024', 'mouse025', 'mouse026', 'mouse027', 'mouse028', 'mouse029', 'mouse030', 'mouse031', 'mouse032', 'mouse033', 'mouse034', 'mouse035', 'mouse037', 'mouse038', 'mouse039', 'mouse040', 'mouse041', 'mouse042', 'mouse044', 'mouse045', 'mouse046', 'mouse047', 'mouse048', 'mouse049', 'mouse050', 'mouse051', 'mouse052', 'mouse053', 'mouse054', 'mouse055', 'mouse056', 'mouse057', 'mouse058', 'mouse059', 'mouse060', 'mouse061', 'mouse062', 'mouse063', 'mouse064', 'mouse065', 'mouse066', 'mouse067', 'mouse068', 'mouse069', 'mouse070']
# ...

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c3.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c3.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml
# Out:
# here
# mod types ['dtcn']
# frac 1
# n_sessions 68
# ['mouse001', 'mouse002', 'mouse003', 'mouse004', 'mouse005', 'mouse006', 'mouse007', 'mouse008', 'mouse009', 'mouse010', 'mouse011', 'mouse012', 'mouse013', 'mouse014', 'mouse015', 'mouse016', 'mouse017', 'mouse018', 'mouse019', 'mouse020', 'mouse021', 'mouse022', 'mouse023', 'mouse024', 'mouse025', 'mouse026', 'mouse027', 'mouse028', 'mouse029', 'mouse030', 'mouse031', 'mouse032', 'mouse033', 'mouse034', 'mouse035', 'mouse037', 'mouse038', 'mouse039', 'mouse040', 'mouse041', 'mouse042', 'mouse044', 'mouse045', 'mouse046', 'mouse047', 'mouse048', 'mouse049', 'mouse050', 'mouse051', 'mouse052', 'mouse053', 'mouse054', 'mouse055', 'mouse056', 'mouse057', 'mouse058', 'mouse059', 'mouse060', 'mouse061', 'mouse062', 'mouse063', 'mouse064', 'mouse065', 'mouse066', 'mouse067', 'mouse068', 'mouse069', 'mouse070']
# ...

# %%
# tcn pos

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c1.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c1.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml
# Out:
#  20%|████████▍                                  | 10/51 [00:44<02:54,  4.25s/it]Epoch 10, Batch 284, LR: 0.001000
# Epoch 10, Batch 284, LR: 0.001000
# Current epoch: 10, val F1: 0.7530
# Current epoch: 10, val F1: 0.7530
# Best epoch: 10, val F1: 0.7530
# Best epoch: 10, val F1: 0.7530
#  29%|████████████▋                              | 15/51 [01:06<02:29,  4.14s/it]Epoch 15, Batch 284, LR: 0.001000
# Epoch 15, Batch 284, LR: 0.001000
# Current epoch: 15, val F1: 0.7597
# Current epoch: 15, val F1: 0.7597
# Best epoch: 15, val F1: 0.7597
# Best epoch: 15, val F1: 0.7597
#  39%|████████████████▊                          | 20/51 [01:28<02:09,  4.17s/it]Epoch 20, Batch 284, LR: 0.001000
# Epoch 20, Batch 284, LR: 0.001000
# Current epoch: 20, val F1: 0.7707
# Current epoch: 20, val F1: 0.7707
# Best epoch: 20, val F1: 0.7707
# Best epoch: 20, val F1: 0.7707
#  49%|█████████████████████                      | 25/51 [01:50<01:49,  4.20s/it]Epoch 25, Batch 284, LR: 0.001000
# ...

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c2.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c2.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c3.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c3.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

# %%
# simba

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c4.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c4.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml


! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c4.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c4.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml
# Out:
# here
# mod types ['dtcn']
# frac 1
# n_sessions 68
# ['mouse001', 'mouse002', 'mouse003', 'mouse004', 'mouse005', 'mouse006', 'mouse007', 'mouse008', 'mouse009', 'mouse010', 'mouse011', 'mouse012', 'mouse013', 'mouse014', 'mouse015', 'mouse016', 'mouse017', 'mouse018', 'mouse019', 'mouse020', 'mouse021', 'mouse022', 'mouse023', 'mouse024', 'mouse025', 'mouse026', 'mouse027', 'mouse028', 'mouse029', 'mouse030', 'mouse031', 'mouse032', 'mouse033', 'mouse034', 'mouse035', 'mouse037', 'mouse038', 'mouse039', 'mouse040', 'mouse041', 'mouse042', 'mouse044', 'mouse045', 'mouse046', 'mouse047', 'mouse048', 'mouse049', 'mouse050', 'mouse051', 'mouse052', 'mouse053', 'mouse054', 'mouse055', 'mouse056', 'mouse057', 'mouse058', 'mouse059', 'mouse060', 'mouse061', 'mouse062', 'mouse063', 'mouse064', 'mouse065', 'mouse066', 'mouse067', 'mouse068', 'mouse069', 'mouse070']
# ...

# %%
# treba

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c5.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c5.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml


! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c5.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c5.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

# %%
# pca

# %%
! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c6.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre wv2 --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c6.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c1.yaml


! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_tcn --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c6.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml

! python /home/bsb2144/daart/examples/fit_models_subsample_loop.py --pre w --fit_mlp --frac 1 --dataset calms21 --n_samples 1 --data /home/bsb2144/daart_utils/configs/data_c6.yaml --model /home/bsb2144/daart_utils/configs/model_c1.yaml --train /home/bsb2144/daart_utils/configs/train_c2.yaml
